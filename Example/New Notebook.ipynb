# %% [markdown]
# ## Structured Streaming using the Python DataFrames API
#
# Apache Spark includes a high-level stream processing API

# %% [markdown]
# ### Sample Data
#
# We have some sample action data as files in `/databricks-datasets/structured-streaming/events/` which we are going to use to build this application

# %%
# %fs ls /databricks-datasets/structured-streaming/events/

# %%
# %fs head /databricks-datasets/structured-streaming/events/file-0.json
